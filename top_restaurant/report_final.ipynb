# %% [markdown]
# #### Top Ten rated restaurants & the most popular restaurants in each city
#
# > ##### Top ten rated restaurants
# >
# > > In this section, We used spark to read the JSON databae and create a dataframe. Firset, we selected the required columns (name, categories, review_count, stars) from this dataframe. Because the categories in the data not only include restaurants, but also many other businesses. So we extracted `Restaurants and food` as keywords. To filter out restaurants with too few user reviews, here we filter out restaurants with less than 100 reviews. Finally, sort accordind to stars and review_count and finally take out the top ten restaurants from all regions.
# > > Here, to visualize the data, we chose to draw the table as a histogram.
# > >
# > > ![img](data:image/png;base64,...)
# >
# > ##### The most popular restaurants in each city.
# >
# > > In the previous section, we have filtered out business other than Food and Restaurant. Here we directly use the processed data to implement this section. By finding the max reviews of each city, we can get the following table.
# > >
# > > |                      name | review_count | state |  latitude |   longitude |      city |
# > > | ------------------------: | -----------: | ----: | --------: | ----------: | --------: |
# > > |          Bacchanal Buffet |        10129 |    NV | 36.115929 | -115.176238 | Las Vegas |
# > > |    Snooze, An A.M. Eatery |         3515 |    AZ | 33.508204 | -112.037033 |   Phoenix |
# > > | Pai Northern Thai Kitchen |         2758 |    ON | 43.647866 |  -79.388685 |   Toronto |
# > > |                Schwartz's |         2667 |    QC | 45.516353 |  -73.577642 |  Montréal |
# > >
# > > 100 rows × 6 columns
# > >
# > > To visualize the data, we used `dash` and `plotly.express` to mark the most popular restaurants in each city on the map. Different states can be selected in the dropdown menu. After selection, the map will jump to the position of this state and display the most popular restaurants in each city in this state. When the mouse is moved to the point representing each restaurant, the name, city, and other information about the restaurant will be displayed.
# > >
# > >
